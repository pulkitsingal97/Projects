# %%
# Hinge Loss without Regularization

# %%
# Import libraries

import numpy as np               
import matplotlib.pyplot as plt 
import tensorflow as tf          
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from sklearn.model_selection import train_test_split 
import os                        
import cv2

# %%
# Collect and preprocess data

req_height = 64
req_width = 64
channels = 3

def load_and_preprocess_data(data_dir, image_size=(req_height, req_width)):
    data = []
    labels = []

    for folder_name in os.listdir(data_dir):
        label = 1 if folder_name == 'faces' else 0
        folder_path = os.path.join(data_dir, folder_name)

        for filename in os.listdir(folder_path):
            img_path = os.path.join(folder_path, filename)
            img = cv2.imread(img_path)
            img = cv2.resize(img, image_size)
            img = img.astype("float32") / 255.0
            data.append(img)
            labels.append(label)

    data = np.array(data)
    labels = np.array(labels)

    return data, labels

data_dir = 'dataset'
data, labels = load_and_preprocess_data(data_dir)

print("Data shape:", data.shape)
print("Labels shape:", labels.shape)
# Out:
# Data shape: (2560, 64, 64, 3)
# Labels shape: (2560,)

# %%
# Split the dataset

x_train, x_temp, y_train, y_temp = train_test_split(data, labels, test_size=0.3, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5, random_state=42)

# %%
# Create a neural network model

model = Sequential([
    Flatten(input_shape=(req_width, req_height, channels)),
    Dense(256, activation='sigmoid'),  # Hidden layer 1
    Dense(128, activation='sigmoid'),  # Hidden layer 2
    Dense(1, activation='sigmoid')     # Output layer (binary classification)
])

# %%
# Compile the model with hinge loss or cross-entropy loss

# a) Hinge loss
model.compile(optimizer='adam', loss='hinge', metrics=['accuracy'])

# b) Cross-entropy loss
# model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model

train_loss_values = []
train_accuracy_values = []
validation_loss_values = []
validation_accuracy_values = []
test_loss_values = []
test_accuracy_values = []
epochs = []

num_epochs = 20

for epoch in range(num_epochs):
    history = model.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=1)

    train_loss, train_accuracy = model.evaluate(x_train, y_train, verbose=0)
    validation_loss, validation_accuracy = model.evaluate(x_val, y_val, verbose=0)
    test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
    
    train_loss_values.append(train_loss)
    train_accuracy_values.append(train_accuracy)
    validation_loss_values.append(validation_loss)
    validation_accuracy_values.append(validation_accuracy)
    test_loss_values.append(test_loss)    
    test_accuracy_values.append(test_accuracy)
    epochs.append(epoch + 1)

    print(f"Epoch {epoch + 1}/{num_epochs}, Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Validation Loss: {validation_loss:.4f}, Validation Accuracy: {validation_accuracy:.4f}, Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# 56/56 [==============================] - 5s 61ms/step - loss: 1.0028 - accuracy: 0.6127 - val_loss: 1.0003 - val_accuracy: 0.6406
# Epoch 1/20, Train Loss: 1.0003, Train Accuracy: 0.6127, Validation Loss: 1.0003, Validation Accuracy: 0.6406, Test Loss: 1.0002, Test Accuracy: 0.6016
# 56/56 [==============================] - 2s 44ms/step - loss: 1.0002 - accuracy: 0.6127 - val_loss: 1.0002 - val_accuracy: 0.6406
# Epoch 2/20, Train Loss: 1.0002, Train Accuracy: 0.6127, Validation Loss: 1.0002, Validation Accuracy: 0.6406, Test Loss: 1.0002, Test Accuracy: 0.6016
# 56/56 [==============================] - 3s 46ms/step - loss: 1.0001 - accuracy: 0.6127 - val_loss: 1.0001 - val_accuracy: 0.6406
# Epoch 3/20, Train Loss: 1.0001, Train Accuracy: 0.6127, Validation Loss: 1.0001, Validation Accuracy: 0.6406, Test Loss: 1.0001, Test Accuracy: 0.6016
# 56/56 [==============================] - 3s 44ms/step - loss: 1.0001 - accuracy: 0.6127 - val_loss: 1.0001 - val_accuracy: 0.6406
# Epoch 4/20, Train Loss: 1.0001, Train Accuracy: 0.6127, Validation Loss: 1.0001, Validation Accuracy: 0.6406, Test Loss: 1.0001, Test Accuracy: 0.6016
# 56/56 [==============================] - 2s 42ms/step - loss: 1.0001 - accuracy: 0.6127 - val_loss: 1.0001 - val_accuracy: 0.6406
# Epoch 5/20, Train Loss: 1.0001, Train Accuracy: 0.6127, Validation Loss: 1.0001, Validation Accuracy: 0.6406, Test Loss: 1.0001, Test Accuracy: 0.6016
# 56/56 [==============================] - 2s 44ms/step - loss: 1.0001 - accuracy: 0.6127 - val_loss: 1.0001 - val_accuracy: 0.6406
# Epoch 6/20, Train Loss: 1.0001, Train Accuracy: 0.6127, Validation Loss: 1.0001, Validation Accuracy: 0.6406, Test Loss: 1.0001, Test Accuracy: 0.6016
# 56/56 [==============================] - 2s 41ms/step - loss: 1.0001 - accuracy: 0.6127 - val_loss: 1.0001 - val_accuracy: 0.6406
# Epoch 7/20, Train Loss: 1.0001, Train Accuracy: 0.6127, Validation Loss: 1.0001, Validation Accuracy: 0.6406, Test Loss: 1.0000, Test Accuracy: 0.6016
# 56/56 [==============================] - 2s 42ms/step - loss: 1.0000 - accuracy: 0.6127 - val_loss: 1.0001 - val_accuracy: 0.6406
# Epoch 8/20, Train Loss: 1.0000, Train Accuracy: 0.6127, Validation Loss: 1.0001, Validation Accuracy: 0.6406, Test Loss: 1.0000, Test Accuracy: 0.6016
# 56/56 [==============================] - 3s 48ms/step - loss: 1.0000 - accuracy: 0.6127 - val_loss: 1.0000 - val_accuracy: 0.6406
# Epoch 9/20, Train Loss: 1.0000, Train Accuracy: 0.6127, Validation Loss: 1.0000, Validation Accuracy: 0.6406, Test Loss: 1.0000, Test Accuracy: 0.6016
# 56/56 [==============================] - 2s 41ms/step - loss: 1.0000 - accuracy: 0.6127 - val_loss: 1.0000 - val_accuracy: 0.6406
# Epoch 10/20, Train Loss: 1.0000, Train Accuracy: 0.6127, Validation Loss: 1.0000, Validation Accuracy: 0.6406, Test Loss: 1.0000, Test Accuracy: 0.6016
# 56/56 [==============================] - 2s 40ms/step - loss: 1.0000 - accuracy: 0.6127 - val_loss: 1.0000 - val_accuracy: 0.6406
# Epoch 11/20, Train Loss: 1.0000, Train Accuracy: 0.6127, Validation Loss: 1.0000, Validation Accuracy: 0.6406, Test Loss: 1.0000, Test Accuracy: 0.6016
# 56/56 [==============================] - 2s 43ms/step - loss: 1.0000 - accuracy: 0.6127 - val_loss: 1.0000 - val_accuracy: 0.6406
# Epoch 12/20, Train Loss: 1.0000, Train Accuracy: 0.6127, Validation Loss: 1.0000, Validation Accuracy: 0.6406, Test Loss: 1.0000, Test Accuracy: 0.6016
# 56/56 [==============================] - 2s 39ms/step - loss: 1.0000 - accuracy: 0.6127 - val_loss: 1.0000 - val_accuracy: 0.6406
# Epoch 13/20, Train Loss: 1.0000, Train Accuracy: 0.6127, Validation Loss: 1.0000, Validation Accuracy: 0.6406, Test Loss: 1.0000, Test Accuracy: 0.6016
# 56/56 [==============================] - 2s 43ms/step - loss: 1.0000 - accuracy: 0.6127 - val_loss: 1.0000 - val_accuracy: 0.6406
# Epoch 14/20, Train Loss: 1.0000, Train Accuracy: 0.6127, Validation Loss: 1.0000, Validation Accuracy: 0.6406, Test Loss: 1.0000, Test Accuracy: 0.6016
# 56/56 [==============================] - 2s 38ms/step - loss: 1.0000 - accuracy: 0.6127 - val_loss: 1.0000 - val_accuracy: 0.6406
# Epoch 15/20, Train Loss: 1.0000, Train Accuracy: 0.6127, Validation Loss: 1.0000, Validation Accuracy: 0.6406, Test Loss: 1.0000, Test Accuracy: 0.6016
# 56/56 [==============================] - 2s 42ms/step - loss: 1.0000 - accuracy: 0.6127 - val_loss: 1.0000 - val_accuracy: 0.6406
# Epoch 16/20, Train Loss: 1.0000, Train Accuracy: 0.6127, Validation Loss: 1.0000, Validation Accuracy: 0.6406, Test Loss: 1.0000, Test Accuracy: 0.6016
# 56/56 [==============================] - 2s 41ms/step - loss: 1.0000 - accuracy: 0.6127 - val_loss: 1.0000 - val_accuracy: 0.6406
# Epoch 17/20, Train Loss: 1.0000, Train Accuracy: 0.6127, Validation Loss: 1.0000, Validation Accuracy: 0.6406, Test Loss: 1.0000, Test Accuracy: 0.6016
# 56/56 [==============================] - 2s 39ms/step - loss: 1.0000 - accuracy: 0.6127 - val_loss: 1.0000 - val_accuracy: 0.6406
# Epoch 18/20, Train Loss: 1.0000, Train Accuracy: 0.6127, Validation Loss: 1.0000, Validation Accuracy: 0.6406, Test Loss: 1.0000, Test Accuracy: 0.6016
# 56/56 [==============================] - 2s 32ms/step - loss: 1.0000 - accuracy: 0.6127 - val_loss: 1.0000 - val_accuracy: 0.6406
# Epoch 19/20, Train Loss: 1.0000, Train Accuracy: 0.6127, Validation Loss: 1.0000, Validation Accuracy: 0.6406, Test Loss: 1.0000, Test Accuracy: 0.6016
# 56/56 [==============================] - 2s 34ms/step - loss: 1.0000 - accuracy: 0.6127 - val_loss: 1.0000 - val_accuracy: 0.6406
# Epoch 20/20, Train Loss: 1.0000, Train Accuracy: 0.6127, Validation Loss: 1.0000, Validation Accuracy: 0.6406, Test Loss: 1.0000, Test Accuracy: 0.6016

# %%
# Plot the training, validation, and test loss values

plt.plot(epochs, train_loss_values, label='Train Loss')
plt.plot(epochs, validation_loss_values, label='Validation Loss')
plt.plot(epochs, test_loss_values, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('01 Hinge Loss')
plt.savefig('01_Hinge_loss.png')
plt.show()

# %%
# Save the trained model

model.save("01_Hinge_loss.keras")
