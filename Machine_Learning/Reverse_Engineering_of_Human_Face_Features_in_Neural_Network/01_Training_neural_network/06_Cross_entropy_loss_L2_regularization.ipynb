# %%
# Cross-entropy Loss with L2 Regularization

# %%
# Import libraries

import numpy as np               
import matplotlib.pyplot as plt 
import tensorflow as tf          
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from sklearn.model_selection import train_test_split 
import os                        
import cv2                     
from tensorflow.keras.regularizers import l1
from tensorflow.keras.regularizers import l2

# %%
# Collect and preprocess data

req_height = 64
req_width = 64
channels = 3

def load_and_preprocess_data(data_dir, image_size=(req_height, req_width)):
    data = []
    labels = []

    for folder_name in os.listdir(data_dir):
        label = 1 if folder_name == 'faces' else 0
        folder_path = os.path.join(data_dir, folder_name)

        for filename in os.listdir(folder_path):
            img_path = os.path.join(folder_path, filename)
            img = cv2.imread(img_path)
            img = cv2.resize(img, image_size)
            img = img.astype("float32") / 255.0
            data.append(img)
            labels.append(label)   

    data = np.array(data)
    labels = np.array(labels)

    return data, labels

data_dir = 'dataset'
data, labels = load_and_preprocess_data(data_dir)

print("Data shape:", data.shape)
print("Labels shape:", labels.shape)
# Out:
# Data shape: (2560, 64, 64, 3)
# Labels shape: (2560,)

# %%
# Split the dataset

x_train, x_temp, y_train, y_temp = train_test_split(data, labels, test_size=0.3, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5, random_state=42)

# %%
# Create a neural network model

model = Sequential([
    Flatten(input_shape=(req_width, req_height, channels)),
    Dense(256, activation='sigmoid', kernel_regularizer=l2(0.001)),  # Hidden layer 1
    Dense(128, activation='sigmoid', kernel_regularizer=l2(0.001)),  # Hidden layer 2
    Dense(1, activation='sigmoid', kernel_regularizer=l2(0.001))     # Output layer (binary classification)
])

# %%
# Compile the model with hinge loss or cross-entropy loss

# a) Hinge loss
# model.compile(optimizer='adam', loss='hinge', metrics=['accuracy'])

# b) Cross-entropy loss
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model

train_loss_values = []
train_accuracy_values = []
validation_loss_values = []
validation_accuracy_values = []
test_loss_values = []
test_accuracy_values = []
epochs = []

num_epochs = 20

for epoch in range(num_epochs):
    history = model.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=1)

    train_loss, train_accuracy = model.evaluate(x_train, y_train, verbose=0)
    validation_loss, validation_accuracy = model.evaluate(x_val, y_val, verbose=0)
    test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
    
    train_loss_values.append(train_loss)
    train_accuracy_values.append(train_accuracy)
    validation_loss_values.append(validation_loss)
    validation_accuracy_values.append(validation_accuracy)
    test_loss_values.append(test_loss)    
    test_accuracy_values.append(test_accuracy)
    epochs.append(epoch + 1)

    print(f"Epoch {epoch + 1}/{num_epochs}, Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Validation Loss: {validation_loss:.4f}, Validation Accuracy: {validation_accuracy:.4f}, Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# 56/56 [==============================] - 5s 58ms/step - loss: 0.8182 - accuracy: 0.8198 - val_loss: 0.5275 - val_accuracy: 0.9349
# Epoch 1/20, Train Loss: 0.5225, Train Accuracy: 0.9375, Validation Loss: 0.5275, Validation Accuracy: 0.9349, Test Loss: 0.5417, Test Accuracy: 0.9297
# 56/56 [==============================] - 3s 58ms/step - loss: 0.4293 - accuracy: 0.9420 - val_loss: 0.4269 - val_accuracy: 0.9141
# Epoch 2/20, Train Loss: 0.3879, Train Accuracy: 0.9408, Validation Loss: 0.4269, Validation Accuracy: 0.9141, Test Loss: 0.4257, Test Accuracy: 0.9167
# 56/56 [==============================] - 3s 57ms/step - loss: 0.3666 - accuracy: 0.9381 - val_loss: 0.3469 - val_accuracy: 0.9453
# Epoch 3/20, Train Loss: 0.3066, Train Accuracy: 0.9682, Validation Loss: 0.3469, Validation Accuracy: 0.9453, Test Loss: 0.3556, Test Accuracy: 0.9453
# 56/56 [==============================] - 3s 54ms/step - loss: 0.2747 - accuracy: 0.9688 - val_loss: 0.2754 - val_accuracy: 0.9583
# Epoch 4/20, Train Loss: 0.2336, Train Accuracy: 0.9844, Validation Loss: 0.2754, Validation Accuracy: 0.9583, Test Loss: 0.2924, Test Accuracy: 0.9531
# 56/56 [==============================] - 3s 52ms/step - loss: 0.2416 - accuracy: 0.9738 - val_loss: 0.2368 - val_accuracy: 0.9740
# Epoch 5/20, Train Loss: 0.1950, Train Accuracy: 0.9900, Validation Loss: 0.2368, Validation Accuracy: 0.9740, Test Loss: 0.2603, Test Accuracy: 0.9609
# 56/56 [==============================] - 3s 57ms/step - loss: 0.2168 - accuracy: 0.9760 - val_loss: 0.2441 - val_accuracy: 0.9583
# Epoch 6/20, Train Loss: 0.1923, Train Accuracy: 0.9860, Validation Loss: 0.2441, Validation Accuracy: 0.9583, Test Loss: 0.2689, Test Accuracy: 0.9531
# 56/56 [==============================] - 3s 53ms/step - loss: 0.3338 - accuracy: 0.9330 - val_loss: 0.3823 - val_accuracy: 0.9167
# Epoch 7/20, Train Loss: 0.3422, Train Accuracy: 0.9453, Validation Loss: 0.3823, Validation Accuracy: 0.9167, Test Loss: 0.3725, Test Accuracy: 0.9297
# 56/56 [==============================] - 3s 52ms/step - loss: 0.3039 - accuracy: 0.9503 - val_loss: 0.4192 - val_accuracy: 0.8854
# Epoch 8/20, Train Loss: 0.3626, Train Accuracy: 0.9247, Validation Loss: 0.4192, Validation Accuracy: 0.8854, Test Loss: 0.3982, Test Accuracy: 0.9219
# 56/56 [==============================] - 3s 58ms/step - loss: 0.2628 - accuracy: 0.9665 - val_loss: 0.3874 - val_accuracy: 0.9062
# Epoch 9/20, Train Loss: 0.3425, Train Accuracy: 0.9247, Validation Loss: 0.3874, Validation Accuracy: 0.9062, Test Loss: 0.4458, Test Accuracy: 0.8828
# 56/56 [==============================] - 3s 55ms/step - loss: 0.2359 - accuracy: 0.9743 - val_loss: 0.2399 - val_accuracy: 0.9688
# Epoch 10/20, Train Loss: 0.1881, Train Accuracy: 0.9894, Validation Loss: 0.2399, Validation Accuracy: 0.9688, Test Loss: 0.2595, Test Accuracy: 0.9609
# 56/56 [==============================] - 3s 53ms/step - loss: 0.2468 - accuracy: 0.9609 - val_loss: 0.2423 - val_accuracy: 0.9740
# Epoch 11/20, Train Loss: 0.2185, Train Accuracy: 0.9860, Validation Loss: 0.2423, Validation Accuracy: 0.9740, Test Loss: 0.2744, Test Accuracy: 0.9531
# 56/56 [==============================] - 3s 58ms/step - loss: 0.2169 - accuracy: 0.9777 - val_loss: 0.3215 - val_accuracy: 0.9193
# Epoch 12/20, Train Loss: 0.2749, Train Accuracy: 0.9358, Validation Loss: 0.3215, Validation Accuracy: 0.9193, Test Loss: 0.3706, Test Accuracy: 0.9245
# 56/56 [==============================] - 3s 54ms/step - loss: 0.1890 - accuracy: 0.9782 - val_loss: 0.2573 - val_accuracy: 0.9427
# Epoch 13/20, Train Loss: 0.1833, Train Accuracy: 0.9866, Validation Loss: 0.2573, Validation Accuracy: 0.9427, Test Loss: 0.2522, Test Accuracy: 0.9453
# 56/56 [==============================] - 3s 55ms/step - loss: 0.1656 - accuracy: 0.9849 - val_loss: 0.2012 - val_accuracy: 0.9609
# Epoch 14/20, Train Loss: 0.1506, Train Accuracy: 0.9939, Validation Loss: 0.2012, Validation Accuracy: 0.9609, Test Loss: 0.2495, Test Accuracy: 0.9557
# 56/56 [==============================] - 3s 58ms/step - loss: 0.1685 - accuracy: 0.9827 - val_loss: 0.2034 - val_accuracy: 0.9740
# Epoch 15/20, Train Loss: 0.1470, Train Accuracy: 0.9939, Validation Loss: 0.2034, Validation Accuracy: 0.9740, Test Loss: 0.2384, Test Accuracy: 0.9479
# 56/56 [==============================] - 3s 58ms/step - loss: 0.1470 - accuracy: 0.9894 - val_loss: 0.1849 - val_accuracy: 0.9740
# Epoch 16/20, Train Loss: 0.1295, Train Accuracy: 0.9950, Validation Loss: 0.1849, Validation Accuracy: 0.9740, Test Loss: 0.2404, Test Accuracy: 0.9583
# 56/56 [==============================] - 3s 55ms/step - loss: 0.1507 - accuracy: 0.9866 - val_loss: 0.1882 - val_accuracy: 0.9635
# Epoch 17/20, Train Loss: 0.1218, Train Accuracy: 0.9972, Validation Loss: 0.1882, Validation Accuracy: 0.9635, Test Loss: 0.2189, Test Accuracy: 0.9583
# 56/56 [==============================] - 3s 62ms/step - loss: 0.1249 - accuracy: 0.9927 - val_loss: 0.2415 - val_accuracy: 0.9375
# Epoch 18/20, Train Loss: 0.1728, Train Accuracy: 0.9682, Validation Loss: 0.2415, Validation Accuracy: 0.9375, Test Loss: 0.2910, Test Accuracy: 0.9167
# 56/56 [==============================] - 3s 52ms/step - loss: 0.3032 - accuracy: 0.9213 - val_loss: 0.4902 - val_accuracy: 0.9427
# Epoch 19/20, Train Loss: 0.4773, Train Accuracy: 0.9576, Validation Loss: 0.4902, Validation Accuracy: 0.9427, Test Loss: 0.4981, Test Accuracy: 0.9323
# 56/56 [==============================] - 3s 54ms/step - loss: 0.3492 - accuracy: 0.9559 - val_loss: 0.2895 - val_accuracy: 0.9557
# Epoch 20/20, Train Loss: 0.2465, Train Accuracy: 0.9760, Validation Loss: 0.2895, Validation Accuracy: 0.9557, Test Loss: 0.3233, Test Accuracy: 0.9427

# %%
# Plot the training, validation, and test loss values

plt.plot(epochs, train_loss_values, label='Train Loss')
plt.plot(epochs, validation_loss_values, label='Validation Loss')
plt.plot(epochs, test_loss_values, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('06 Cross-entropy Loss with L2 Regularization')
plt.savefig('06_Cross_entropy_loss_L2_regularization.png')
plt.show()

# %%
# Save the trained model

model.save("06_Cross_entropy_loss_L2_regularization.keras")
