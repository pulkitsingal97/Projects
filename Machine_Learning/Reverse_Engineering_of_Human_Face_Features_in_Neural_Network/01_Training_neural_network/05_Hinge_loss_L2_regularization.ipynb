# %%
# Hinge Loss with L2 Regularization

# %%
# Import libraries

import numpy as np               
import matplotlib.pyplot as plt 
import tensorflow as tf          
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from sklearn.model_selection import train_test_split 
import os                        
import cv2                     
from tensorflow.keras.regularizers import l1
from tensorflow.keras.regularizers import l2

# %%
# Collect and preprocess data

req_height = 64
req_width = 64
channels = 3

def load_and_preprocess_data(data_dir, image_size=(req_height, req_width)):
    data = []
    labels = []

    for folder_name in os.listdir(data_dir):
        label = 1 if folder_name == 'faces' else 0
        folder_path = os.path.join(data_dir, folder_name)

        for filename in os.listdir(folder_path):
            img_path = os.path.join(folder_path, filename)
            img = cv2.imread(img_path)
            img = cv2.resize(img, image_size)
            img = img.astype("float32") / 255.0
            data.append(img)
            labels.append(label)   

    data = np.array(data)
    labels = np.array(labels)

    return data, labels

data_dir = 'dataset'
data, labels = load_and_preprocess_data(data_dir)

print("Data shape:", data.shape)
print("Labels shape:", labels.shape)
# Out:
# Data shape: (2560, 64, 64, 3)
# Labels shape: (2560,)

# %%
# Split the dataset

x_train, x_temp, y_train, y_temp = train_test_split(data, labels, test_size=0.3, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5, random_state=42)

# %%
# Create a neural network model

model = Sequential([
    Flatten(input_shape=(req_width, req_height, channels)),
    Dense(256, activation='sigmoid', kernel_regularizer=l2(0.001)),  # Hidden layer 1
    Dense(128, activation='sigmoid', kernel_regularizer=l2(0.001)),  # Hidden layer 2
    Dense(1, activation='sigmoid', kernel_regularizer=l2(0.001))     # Output layer (binary classification)
])

# %%
# Compile the model with hinge loss or cross-entropy loss

# a) Hinge loss
model.compile(optimizer='adam', loss='hinge', metrics=['accuracy'])

# b) Cross-entropy loss
# model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model

train_loss_values = []
train_accuracy_values = []
validation_loss_values = []
validation_accuracy_values = []
test_loss_values = []
test_accuracy_values = []
epochs = []

num_epochs = 20

for epoch in range(num_epochs):
    history = model.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=1)

    train_loss, train_accuracy = model.evaluate(x_train, y_train, verbose=0)
    validation_loss, validation_accuracy = model.evaluate(x_val, y_val, verbose=0)
    test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
    
    train_loss_values.append(train_loss)
    train_accuracy_values.append(train_accuracy)
    validation_loss_values.append(validation_loss)
    validation_accuracy_values.append(validation_accuracy)
    test_loss_values.append(test_loss)    
    test_accuracy_values.append(test_accuracy)
    epochs.append(epoch + 1)

    print(f"Epoch {epoch + 1}/{num_epochs}, Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Validation Loss: {validation_loss:.4f}, Validation Accuracy: {validation_accuracy:.4f}, Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# 56/56 [==============================] - 3s 40ms/step - loss: 1.2275 - accuracy: 0.6177 - val_loss: 1.1037 - val_accuracy: 0.6406
# Epoch 1/20, Train Loss: 1.1030, Train Accuracy: 0.6127, Validation Loss: 1.1037, Validation Accuracy: 0.6406, Test Loss: 1.1024, Test Accuracy: 0.6016
# 56/56 [==============================] - 2s 35ms/step - loss: 1.0596 - accuracy: 0.6155 - val_loss: 0.9685 - val_accuracy: 0.7760
# Epoch 2/20, Train Loss: 0.9556, Train Accuracy: 0.7433, Validation Loss: 0.9685, Validation Accuracy: 0.7760, Test Loss: 0.9434, Test Accuracy: 0.7318
# Epoch 12/20, Train Loss: 0.8705, Train Accuracy: 0.8203, Validation Loss: 0.9025, Validation Accuracy: 0.8151, Test Loss: 0.8873, Test Accuracy: 0.7917
# 56/56 [==============================] - 3s 57ms/step - loss: 0.7408 - accuracy: 0.9509 - val_loss: 0.7768 - val_accuracy: 0.9505
# Epoch 13/20, Train Loss: 0.7384, Train Accuracy: 0.9559, Validation Loss: 0.7768, Validation Accuracy: 0.9505, Test Loss: 0.7508, Test Accuracy: 0.9297
# 56/56 [==============================] - 3s 53ms/step - loss: 0.7262 - accuracy: 0.9609 - val_loss: 0.8473 - val_accuracy: 0.8724
# Epoch 14/20, Train Loss: 0.8126, Train Accuracy: 0.8728, Validation Loss: 0.8473, Validation Accuracy: 0.8724, Test Loss: 0.8240, Test Accuracy: 0.8542
# 56/56 [==============================] - 3s 52ms/step - loss: 0.7330 - accuracy: 0.9576 - val_loss: 0.7534 - val_accuracy: 0.9714
# Epoch 15/20, Train Loss: 0.7051, Train Accuracy: 0.9810, Validation Loss: 0.7534, Validation Accuracy: 0.9714, Test Loss: 0.7220, Test Accuracy: 0.9531
# 56/56 [==============================] - 3s 57ms/step - loss: 0.8951 - accuracy: 0.7874 - val_loss: 1.0629 - val_accuracy: 0.6406
# Epoch 16/20, Train Loss: 1.0628, Train Accuracy: 0.6127, Validation Loss: 1.0629, Validation Accuracy: 0.6406, Test Loss: 1.0609, Test Accuracy: 0.6042
# 56/56 [==============================] - 3s 54ms/step - loss: 1.0537 - accuracy: 0.6133 - val_loss: 1.0441 - val_accuracy: 0.6432
# Epoch 17/20, Train Loss: 1.0429, Train Accuracy: 0.6150, Validation Loss: 1.0441, Validation Accuracy: 0.6432, Test Loss: 1.0390, Test Accuracy: 0.6068
# 56/56 [==============================] - 3s 57ms/step - loss: 0.8640 - accuracy: 0.8610 - val_loss: 0.8328 - val_accuracy: 0.8958
# Epoch 18/20, Train Loss: 0.8022, Train Accuracy: 0.8990, Validation Loss: 0.8328, Validation Accuracy: 0.8958, Test Loss: 0.8105, Test Accuracy: 0.8802
# 56/56 [==============================] - 3s 56ms/step - loss: 0.7657 - accuracy: 0.9375 - val_loss: 0.7987 - val_accuracy: 0.9245
# Epoch 19/20, Train Loss: 0.7637, Train Accuracy: 0.9342, Validation Loss: 0.7987, Validation Accuracy: 0.9245, Test Loss: 0.7693, Test Accuracy: 0.9193
# 56/56 [==============================] - 3s 53ms/step - loss: 0.7328 - accuracy: 0.9626 - val_loss: 0.7738 - val_accuracy: 0.9479
# Epoch 20/20, Train Loss: 0.7376, Train Accuracy: 0.9475, Validation Loss: 0.7738, Validation Accuracy: 0.9479, Test Loss: 0.7434, Test Accuracy: 0.9453

# %%
# Plot the training, validation, and test loss values

plt.plot(epochs, train_loss_values, label='Train Loss')
plt.plot(epochs, validation_loss_values, label='Validation Loss')
plt.plot(epochs, test_loss_values, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('05 Hinge Loss with L2 Regularization')
plt.savefig('05_Hinge_loss_L2_regularization.png')
plt.show()

# %%
# Save the trained model

model.save("05_Hinge_loss_L2_regularization.keras")
