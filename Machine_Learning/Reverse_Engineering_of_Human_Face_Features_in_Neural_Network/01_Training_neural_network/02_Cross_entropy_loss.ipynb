# %%
# Cross-entropy Loss without Regularization

# %%
# Import libraries

import numpy as np               
import matplotlib.pyplot as plt 
import tensorflow as tf          
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense
from sklearn.model_selection import train_test_split 
import os                        
import cv2

# %%
# Collect and preprocess data

req_height = 64
req_width = 64
channels = 3

def load_and_preprocess_data(data_dir, image_size=(req_height, req_width)):
    data = []
    labels = []

    for folder_name in os.listdir(data_dir):
        label = 1 if folder_name == 'faces' else 0
        folder_path = os.path.join(data_dir, folder_name)

        for filename in os.listdir(folder_path):
            img_path = os.path.join(folder_path, filename)
            img = cv2.imread(img_path)
            img = cv2.resize(img, image_size)
            img = img.astype("float32") / 255.0
            data.append(img)
            labels.append(label)   

    data = np.array(data)
    labels = np.array(labels)

    return data, labels

data_dir = 'dataset'
data, labels = load_and_preprocess_data(data_dir)

print("Data shape:", data.shape)
print("Labels shape:", labels.shape)
# Out:
# Data shape: (2560, 64, 64, 3)
# Labels shape: (2560,)

# %%
# Split the dataset

x_train, x_temp, y_train, y_temp = train_test_split(data, labels, test_size=0.3, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5, random_state=42)

# %%
# Create a neural network model

model = Sequential([
    Flatten(input_shape=(req_width, req_height, channels)),
    Dense(256, activation='sigmoid'),  # Hidden layer 1
    Dense(128, activation='sigmoid'),  # Hidden layer 2
    Dense(1, activation='sigmoid')     # Output layer (binary classification)
])

# %%
# Compile the model with hinge loss or cross-entropy loss

# a) Hinge loss
# model.compile(optimizer='adam', loss='hinge', metrics=['accuracy'])

# b) Cross-entropy loss
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model

train_loss_values = []
train_accuracy_values = []
validation_loss_values = []
validation_accuracy_values = []
test_loss_values = []
test_accuracy_values = []
epochs = []

num_epochs = 20

for epoch in range(num_epochs):
    history = model.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=1)

    train_loss, train_accuracy = model.evaluate(x_train, y_train, verbose=0)
    validation_loss, validation_accuracy = model.evaluate(x_val, y_val, verbose=0)
    test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
    
    train_loss_values.append(train_loss)
    train_accuracy_values.append(train_accuracy)
    validation_loss_values.append(validation_loss)
    validation_accuracy_values.append(validation_accuracy)
    test_loss_values.append(test_loss)    
    test_accuracy_values.append(test_accuracy)
    epochs.append(epoch + 1)

    print(f"Epoch {epoch + 1}/{num_epochs}, Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Validation Loss: {validation_loss:.4f}, Validation Accuracy: {validation_accuracy:.4f}, Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# 56/56 [==============================] - 5s 60ms/step - loss: 0.6881 - accuracy: 0.5848 - val_loss: 0.6480 - val_accuracy: 0.6406
# Epoch 1/20, Train Loss: 0.6646, Train Accuracy: 0.6127, Validation Loss: 0.6480, Validation Accuracy: 0.6406, Test Loss: 0.6712, Test Accuracy: 0.6016
# 56/56 [==============================] - 3s 49ms/step - loss: 0.6554 - accuracy: 0.6127 - val_loss: 0.6257 - val_accuracy: 0.6406
# Epoch 2/20, Train Loss: 0.6328, Train Accuracy: 0.6127, Validation Loss: 0.6257, Validation Accuracy: 0.6406, Test Loss: 0.6365, Test Accuracy: 0.6016
# 56/56 [==============================] - 3s 48ms/step - loss: 0.6156 - accuracy: 0.6752 - val_loss: 0.5787 - val_accuracy: 0.6406
# 56/56 [==============================] - 3s 49ms/step - loss: 0.1039 - accuracy: 0.9688 - val_loss: 0.2362 - val_accuracy: 0.8646
# Epoch 13/20, Train Loss: 0.2071, Train Accuracy: 0.8655, Validation Loss: 0.2362, Validation Accuracy: 0.8646, Test Loss: 0.2949, Test Accuracy: 0.8411
# 56/56 [==============================] - 3s 49ms/step - loss: 0.1149 - accuracy: 0.9654 - val_loss: 0.1599 - val_accuracy: 0.9505
# Epoch 14/20, Train Loss: 0.0792, Train Accuracy: 0.9810, Validation Loss: 0.1599, Validation Accuracy: 0.9505, Test Loss: 0.1551, Test Accuracy: 0.9505
# 56/56 [==============================] - 3s 51ms/step - loss: 0.0916 - accuracy: 0.9721 - val_loss: 0.1971 - val_accuracy: 0.9427
# Epoch 15/20, Train Loss: 0.1116, Train Accuracy: 0.9816, Validation Loss: 0.1971, Validation Accuracy: 0.9427, Test Loss: 0.1859, Test Accuracy: 0.9557
# 56/56 [==============================] - 3s 47ms/step - loss: 0.0610 - accuracy: 0.9855 - val_loss: 0.1238 - val_accuracy: 0.9609
# Epoch 16/20, Train Loss: 0.0553, Train Accuracy: 0.9849, Validation Loss: 0.1238, Validation Accuracy: 0.9609, Test Loss: 0.1718, Test Accuracy: 0.9453
# 56/56 [==============================] - 3s 54ms/step - loss: 0.0633 - accuracy: 0.9816 - val_loss: 0.1685 - val_accuracy: 0.9349
# Epoch 17/20, Train Loss: 0.0961, Train Accuracy: 0.9593, Validation Loss: 0.1685, Validation Accuracy: 0.9349, Test Loss: 0.2321, Test Accuracy: 0.9141
# 56/56 [==============================] - 3s 50ms/step - loss: 0.0602 - accuracy: 0.9838 - val_loss: 0.0938 - val_accuracy: 0.9635
# Epoch 18/20, Train Loss: 0.0324, Train Accuracy: 0.9944, Validation Loss: 0.0938, Validation Accuracy: 0.9635, Test Loss: 0.1276, Test Accuracy: 0.9609
# 56/56 [==============================] - 3s 48ms/step - loss: 0.0385 - accuracy: 0.9916 - val_loss: 0.1198 - val_accuracy: 0.9583
# Epoch 19/20, Train Loss: 0.0465, Train Accuracy: 0.9900, Validation Loss: 0.1198, Validation Accuracy: 0.9583, Test Loss: 0.2012, Test Accuracy: 0.9375
# 56/56 [==============================] - 3s 51ms/step - loss: 0.0616 - accuracy: 0.9821 - val_loss: 0.0983 - val_accuracy: 0.9688
# Epoch 20/20, Train Loss: 0.0367, Train Accuracy: 0.9955, Validation Loss: 0.0983, Validation Accuracy: 0.9688, Test Loss: 0.1472, Test Accuracy: 0.9583

# %%
# Plot the training, validation, and test loss values

plt.plot(epochs, train_loss_values, label='Train Loss')
plt.plot(epochs, validation_loss_values, label='Validation Loss')
plt.plot(epochs, test_loss_values, label='Test Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('02 Cross-entropy Loss')
plt.savefig('02_Cross_entropy_loss.png')
plt.show()

# %%
# Save the trained model

model.save("02_Cross_entropy_loss.keras")
